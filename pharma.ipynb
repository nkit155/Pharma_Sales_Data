# %%
import pandas as pd

# %% [markdown]
# Read and Load the data

# %%
data = pd.read_csv("pharma-data.csv")
data
# Out:
#                    Distributor                               Customer Name  \
# 0       Gottlieb-Cruickshank                       Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                    Feest PLC
# 2       Gottlieb-Cruickshank          Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                         Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# ...                        ...                                         ...
# 254077    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 254078    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 254079    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 254080    Bashirian-Kassulke                        Balistreri Group Pharm
# 254081    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %% [markdown]
# Define the how much columns,rows in dataframe

# %%
data.shape
# Out:
# (254082, 18)

# %% [markdown]
# convert the all columns to list

# %%
print(data.columns.tolist())
# Out:
# ['Distributor', 'Customer Name', 'City', 'Country', 'Latitude', 'Longitude', 'Channel', 'Sub-channel', 'Product Name', 'Product Class', 'Quantity', 'Price', 'Sales', 'Month', 'Year', 'Name of Sales Rep', 'Manager', 'Sales Team']

# %% [markdown]
# Select the top 5 row of datafrmae

# %%
data.head(5)
# Out:
#               Distributor                         Customer Name     City  \
# 0  Gottlieb-Cruickshank                 Zieme, Doyle and Kunze    Lublin
# 1  Gottlieb-Cruickshank                              Feest PLC   Świecie
# 2  Gottlieb-Cruickshank    Medhurst-Beer Pharmaceutical Limited   Rybnik
# 3  Gottlieb-Cruickshank                   Barton Ltd Pharma Plc  Czeladź
# 4  Gottlieb-Cruickshank                    Keeling LLC Pharmacy  Olsztyn
#
#   Country  Latitude  Longitude   Channel  Sub-channel            Product Name  \
# 0  Poland   51.2333    22.5667  Hospital      Private              Topipizole
# 1  Poland   53.4167    18.4333  Pharmacy       Retail            Choriotrisin
# 2  Poland   50.0833    18.5000  Pharmacy  Institution               Acantaine
# 3  Poland   50.3333    19.0833  Hospital      Private    Lioletine Refliruvax
# 4  Poland   53.7800    20.4942  Pharmacy       Retail  Oxymotroban Fexoformin
#
# ...

# %% [markdown]
# select the last 5 row of dataframe

# %%
data.tail(5)
# Out:
#                  Distributor                               Customer Name  \
# 254077  Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 254078  Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 254079  Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 254080  Bashirian-Kassulke                        Balistreri Group Pharm
# 254081  Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
#                  City  Country  Latitude  Longitude   Channel Sub-channel  \
# 254077           Lauf  Germany   49.5103    11.2772  Hospital     Private
# 254078        Aichach  Germany   48.4500    11.1333  Hospital     Private
# 254079  Wilhelmshaven  Germany   53.5167     8.1333  Pharmacy      Retail
# 254080      Böblingen  Germany   48.6833     9.0000  Hospital  Government
# 254081            Hof  Germany   50.3167    11.9167  Pharmacy      Retail
#
#                  Product Name     Product Class  Quantity  Price     Sales  \
# ...

# %% [markdown]
# define the datatypesof all columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254082 entries, 0 to 254081
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Distributor        254082 non-null  object
#  1   Customer Name      254082 non-null  object
#  2   City               254082 non-null  object
#  3   Country            254082 non-null  object
#  4   Latitude           254082 non-null  float64
#  5   Longitude          254082 non-null  float64
#  6   Channel            254082 non-null  object
#  7   Sub-channel        254082 non-null  object
#  8   Product Name       254082 non-null  object
#  9   Product Class      254082 non-null  object
#  10  Quantity           254082 non-null  float64
#  11  Price              254082 non-null  int64
#  12  Sales              254082 non-null  float64
#  13  Month              254082 non-null  object
#  14  Year               254082 non-null  int64
# ...

# %% [markdown]
# count the unique value of customer column

# %%
data['Customer Name'].nunique()
# Out:
# 751

# %% [markdown]
# convert the datatypes of sale column to integar

# %%
data['Sales'].astype(int)
# Out:
# 0           1472
# 1           4137
# 2           1980
# 3           2610
# 4           9160
#            ...
# 254077    456743
# 254078    294192
# 254079    216960
# 254080     64975
# 254081    124200
# Name: Sales, Length: 254082, dtype: int32

# %%
more_5000=data.loc[data['Sales']>=5000]
more_5000
# Out:
#                    Distributor                               Customer Name  \
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# 6       Gottlieb-Cruickshank                Blick, Pacocha and Schowalter
# 10      Gottlieb-Cruickshank                             Wolff Group Pharm
# 17      Gottlieb-Cruickshank               Koss Ltd Pharmaceutical Limited
# 21      Gottlieb-Cruickshank                      Will and Sons Pharma Plc
# ...                        ...                                         ...
# 254077    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 254078    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 254079    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 254080    Bashirian-Kassulke                        Balistreri Group Pharm
# 254081    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %% [markdown]
# Calculate the total sum of quantity

# %%
data['Quantity'].sum()
# Out:
# 28678778.802551232

# %% [markdown]
# Calculate the average price of price column

# %%
data['Price'].mean()
# Out:
# 412.2077203422517

# %% [markdown]
# Group the data by Sales team and count the number of sales team

# %%
data['Sales Team'].value_counts().reset_index()
# Out:
#   Sales Team  count
# 0      Delta  78244
# 1       Alfa  58705
# 2      Bravo  58652
# 3    Charlie  58481

# %% [markdown]
# calculate the highest sale by customer

# %%
highest_sales_customer=data.loc[data['Sales'].idxmax()]
highest_sales_customer
# Out:
# Distributor           Bashirian-Kassulke
# Customer Name        Mraz-Kutch Pharma Plc
# City                              Butzbach
# Country                            Germany
# Latitude                           50.4367
# Longitude                           8.6622
# Channel                           Pharmacy
# Sub-channel                         Retail
# Product Name                    Ionclotide
# Product Class                   Analgesics
# Quantity                          117600.0
# Price                                  631
# Sales                           74205600.0
# Month                               August
# Year                                  2019
# Name of Sales Rep               Jimmy Grey
# Manager                    Alisha Cordwell
# Sales Team                         Charlie
# Name: 186326, dtype: object

# %% [markdown]
# group the data by product class and sum of total sales

# %%
prod_class_sales=data.groupby('Product Class').agg(class_sales=('Sales','sum'))
prod_class_sales
# Out:
#                    class_sales
# Product Class
# Analgesics        2.371515e+09
# Antibiotics       1.750277e+09
# Antimalarial      1.497455e+09
# Antipiretics      1.883306e+09
# Antiseptics       2.237525e+09
# Mood Stabilizers  2.058910e+09

# %% [markdown]
# descending the data by sales column

# %%
Sales_desc=data.sort_values('Sales',ascending=False)
Sales_desc
# Out:
#                  Distributor  \
# 186326  Bashirian-Kassulke
# 242429       Kozey-Emmerich
# 187345  Bashirian-Kassulke
# 186547  Bashirian-Kassulke
# 202280       Kozey-Emmerich
# ...                      ...
# 121817              Erdman
# 117505              Erdman
# 198471               Koss
# 221786               Koss
# 186202               Koss
#
#                                             Customer Name  \
# 186326                              Mraz-Kutch Pharma Plc
# 242429              Parker, Green and Emmerich Pharma Plc
# 187345                                    Zemlak-Witting
# 186547                                       Streich PLC
# 202280  Prohaska, Bogisich and Gutkowski Pharmaceutica...
# ...                                                   ...
# 121817       Buckridge, Hand and Hyatt Pharmaceutical Ltd
# 117505                  Cassin PLC Pharmaceutical Limited
# 198471                             Schmitt LLC Pharma Plc
# ...

# %% [markdown]
# seelct  two column of data

# %%
selected_colum=['Customer Name','Sales']
data[selected_colum]
# Out:
#                                      Customer Name     Sales
# 0                          Zieme, Doyle and Kunze     1472.0
# 1                                       Feest PLC     4137.0
# 2             Medhurst-Beer Pharmaceutical Limited    1980.0
# 3                            Barton Ltd Pharma Plc    2610.0
# 4                             Keeling LLC Pharmacy    9160.0
# ...                                            ...       ...
# 254077  Koch, Borer and Hagenes Pharmaceutical Ltd  456743.0
# 254078                 Hane Ltd Pharmaceutical Ltd  294192.0
# 254079                      Harris-Conroy Pharmacy  216960.0
# 254080                      Balistreri Group Pharm   64975.0
# 254081              Heathcote, Kovacek and Parker   124200.0
#
# [254082 rows x 2 columns]

# %% [markdown]
# creat the new column of price discount

# %%
data['price_discount']=data['Price']*90/100
data
# Out:
#                    Distributor                               Customer Name  \
# 0       Gottlieb-Cruickshank                       Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                    Feest PLC
# 2       Gottlieb-Cruickshank          Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                         Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# ...                        ...                                         ...
# 254077    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 254078    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 254079    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 254080    Bashirian-Kassulke                        Balistreri Group Pharm
# 254081    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %% [markdown]
# group the data by channel and count the number of product

# %%
channel_prod_count=data.groupby('Channel').agg(prod_count=('Product Name','count'))
channel_prod_count
# Out:
#           prod_count
# Channel
# Hospital      124111
# Pharmacy      129971

# %% [markdown]
# count the mising value of each column

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Distributor          0
# Customer Name        0
# City                 0
# Country              0
# Latitude             0
# Longitude            0
# Channel              0
# Sub-channel          0
# Product Name         0
# Product Class        0
# Quantity             0
# Price                0
# Sales                0
# Month                0
# Year                 0
# Name of Sales Rep    0
# Manager              0
# Sales Team           0
# price_discount       0
# dtype: int64

# %% [markdown]
# select the data by year=2018

# %%
year_2018=data.loc[data['Year']==2018]
year_2018
# Out:
#                    Distributor                                  Customer Name  \
# 0       Gottlieb-Cruickshank                          Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                       Feest PLC
# 2       Gottlieb-Cruickshank             Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                            Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                             Keeling LLC Pharmacy
# ...                        ...                                            ...
# 150915                 Koss             Kertzmann-Ward Pharmaceutical Limited
# 150916                 Koss              Quigley-Heathcote Pharmaceutical Ltd
# 150917                 Koss                    Monahan Ltd Pharmaceutical Ltd
# 150918                 Koss     Bogan, Jacobs and Kris Pharmaceutical Limited
# 150919                 Koss                   Gulgowski-Vandervort Pharma Plc
#
# ...

# %% [markdown]
# group the data by month and sum of sales column

# %%
sales_per_mon=data.groupby('Month').agg(sales_mon=('Sales','sum')).reset_index()
sales_per_mon
# Out:
#         Month     sales_mon
# 0       April  8.000346e+08
# 1      August  1.186627e+09
# 2    December  9.750071e+08
# 3    February  9.721298e+08
# 4     January  6.741911e+08
# 5        July  1.042537e+09
# 6        June  1.064033e+09
# 7       March  1.108802e+09
# 8         May  8.651872e+08
# 9    November  1.108803e+09
# 10    October  9.716484e+08
# 11  September  1.029988e+09

# %% [markdown]
# group the data by manager,product class and sum of sales column

# %%
manager_class_sales=data.groupby(['Manager','Product Class']).agg(total_sales=('Sales','sum'))
manager_class_sales
# Out:
#                                    total_sales
# Manager         Product Class
# Alisha Cordwell Analgesics        5.778376e+08
#                 Antibiotics       3.893429e+08
#                 Antimalarial      4.660507e+08
#                 Antipiretics      4.370770e+08
#                 Antiseptics       4.781254e+08
#                 Mood Stabilizers  4.765358e+08
# Britanny Bold   Analgesics        6.637879e+08
#                 Antibiotics       5.855665e+08
#                 Antimalarial      4.037058e+08
#                 Antipiretics      5.851767e+08
#                 Antiseptics       7.454998e+08
#                 Mood Stabilizers  6.516047e+08
# James Goodwill  Analgesics        5.027979e+08
#                 Antibiotics       3.932134e+08
#                 Antimalarial      3.117630e+08
#                 Antipiretics      4.412653e+08
#                 Antiseptics       4.960280e+08
#                 Mood Stabilizers  4.359068e+08
# ...

# %%
pivot_table = data.pivot_table(values='Sales', index='Manager', columns='Product Class', aggfunc='sum', fill_value=0).reset_index()
print(pivot_table)
# Out:
# Product Class          Manager    Analgesics   Antibiotics  Antimalarial  \
# 0              Alisha Cordwell  5.778376e+08  3.893429e+08  4.660507e+08
# 1                Britanny Bold  6.637879e+08  5.855665e+08  4.037058e+08
# 2               James Goodwill  5.027979e+08  3.932134e+08  3.117630e+08
# 3                  Tracy Banks  6.270917e+08  3.821545e+08  3.159359e+08
#
# Product Class  Antipiretics   Antiseptics  Mood Stabilizers
# 0              4.370770e+08  4.781254e+08      4.765358e+08
# 1              5.851767e+08  7.454998e+08      6.516047e+08
# 2              4.412653e+08  4.960280e+08      4.359068e+08
# 3              4.197866e+08  5.178715e+08      4.948623e+08

# %% [markdown]
# count the unique value of country column

# %%
data['Country'].nunique()
# Out:
# 2

# %% [markdown]
# count the value of country column

# %%
country_data=data['Country'].value_counts().reset_index()
country_data
# Out:
#    Country   count
# 0  Germany  213598
# 1   Poland   40484

# %% [markdown]
# calculate the maximum price of price column

# %%
data['Price'].max()
# Out:
# 794

# %% [markdown]
# group the data by channel and sum of sales column

# %%
sales_channel=data.groupby('Channel').agg(high_sales_channel=('Sales','mean'))
sales_channel
# Out:
#           high_sales_channel
# Channel
# Hospital        44965.196506
# Pharmacy        47843.843155

# %% [markdown]
# group the data by channel and highest average of sales column

# %%
print(data.groupby('Channel')['Sales'].mean().idxmax())
# Out:
# Pharmacy

# %%
high_sale_year=data.groupby('Year')['Sales'].sum().idxmax()
high_sale_year
# Out:
# 2018

# %% [markdown]
# select the data of polland

# %%
poland_data=data.loc[data['Country']=='Poland']
poland_data
# Out:
#                   Distributor                         Customer Name  \
# 0      Gottlieb-Cruickshank                 Zieme, Doyle and Kunze
# 1      Gottlieb-Cruickshank                              Feest PLC
# 2      Gottlieb-Cruickshank    Medhurst-Beer Pharmaceutical Limited
# 3      Gottlieb-Cruickshank                   Barton Ltd Pharma Plc
# 4      Gottlieb-Cruickshank                    Keeling LLC Pharmacy
# ...                       ...                                   ...
# 40479                 Beier                               Hill Ltd
# 40480                 Beier         Bogan, Jacobs and Kris Pharmacy
# 40481                 Beier        Gerhold, Mills and Effertz Pharm
# 40482                 Beier                Koch, Borer and Hagenes
# 40483                 Beier                     Denesik-Hintz Pharm
#
#                       City Country  Latitude  Longitude   Channel  \
# 0                   Lublin  Poland   51.2333    22.5667  Hospital
# ...

# %% [markdown]
# group the data by country and sum of sales column

# %%
Country_sales=data.groupby('Country')['Sales'].sum().reset_index()
Country_sales
# Out:
#    Country         Sales
# 0  Germany  1.111811e+10
# 1   Poland  6.808798e+08

# %% [markdown]
# group the data by year and month and sum of sales column

# %%
year_mon_avg_sales=data.groupby(['Year','Month'])['Sales'].mean().reset_index()
year_mon_avg_sales
# Out:
#     Year      Month          Sales
# 0   2017      April   47271.052579
# 1   2017     August   45617.377097
# 2   2017   December   57384.856252
# 3   2017   February   46391.984240
# 4   2017    January   37564.230522
# 5   2017       July   48817.236847
# 6   2017       June   53634.028761
# 7   2017      March   44520.720564
# 8   2017        May   43323.285355
# 9   2017   November   48095.308147
# 10  2017    October   46509.504877
# 11  2017  September   55138.052966
# 12  2018      April   35567.321853
# 13  2018     August   35809.696576
# 14  2018   December   32327.691741
# 15  2018   February   34230.040916
# 16  2018    January   34338.100338
# 17  2018       July   37117.507073
# 18  2018       June   47819.029164
# 19  2018      March   44334.954939
# 20  2018        May   31293.714629
# 21  2018   November   35237.130461
# 22  2018    October   36113.516961
# 23  2018  September   40401.909832
# 24  2019      April   50166.995627
# 25  2019     August  108019.642600
# ...

# %% [markdown]
# calculate the top 3 sub channel by sales

# %%
top_sub_channel_sales=data.groupby('Sub-channel')['Sales'].sum().nlargest(3).reset_index()
top_sub_channel_sales
# Out:
#    Sub-channel         Sales
# 0       Retail  3.343097e+09
# 1   Government  3.058240e+09
# 2  Institution  2.875215e+09

# %% [markdown]
# geoup the data by product and sum of sales column

# %%
product_sales=data.groupby('Product Name')['Sales'].sum().reset_index()
product_sales
# Out:
#               Product Name       Sales
# 0             Abatatriptan  74995424.0
# 1       Abilovir Aprotasol  34146429.6
# 2               Abobozolid   7426350.0
# 3    Abranatal Lysoprosate  84577476.0
# 4                  Abtasol  85226882.0
# ..                     ...         ...
# 235             Zithrotrol  14254439.0
# 236              Zonitonin  50508626.0
# 237   Zonixamine Immulinum  49922748.0
# 238               Zynosine   7799526.0
# 239                Zyvance  55639980.0
#
# [240 rows x 2 columns]

# %% [markdown]
# define the row whose maxumum price

# %%
data.loc[data['Price'].idxmax()]
# Out:
# Distributor                    Gottlieb-Cruickshank
# Customer Name        Haley PLC Pharmaceutical Limited
# City                                            Opole
# Country                                        Poland
# Latitude                                      50.6722
# Longitude                                     17.9253
# Channel                                      Pharmacy
# Sub-channel                                    Retail
# Product Name                              Adalatamine
# Product Class                             Antiseptics
# Quantity                                         10.0
# Price                                             794
# Sales                                          7940.0
# Month                                         January
# Year                                             2018
# Name of Sales Rep                        Stella Given
# Manager                               Alisha Cordwell
# ...

# %%
import matplotlib.pyplot as plt

# %%
top_5_prod_sales=product_sales.sort_values('Sales',ascending=False).head(5)
top_5_prod_sales
# Out:
#          Product Name        Sales
# 133        Ionclotide  169083391.0
# 214        Tetratanyl  126091294.0
# 203        Sumanazole  113861431.0
# 61            Betanem  107073473.0
# 95   Docstryl Rivacin  103811886.0

# %% [markdown]
# creat a bar plot of sales by top 5 product

# %%
top_products = data.groupby('Product Name')['Sales'].sum().nlargest(5)
top_products.plot(kind='bar')
# Out:
# <Axes: xlabel='Product Name'>

# %% [markdown]
# creat a scatter plot of price vs quantity

# %%
data.plot.scatter(x='Price',y='Quantity')
plt.show()

# %% [markdown]
# creat a box plot of sales by channel

# %%
data.boxplot(column='Sales', by='Channel')
# Out:
# <Axes: title={'center': 'Sales'}, xlabel='Channel'>

# %% [markdown]
# creat a hitogram chart of quantity column

# %%
data['Quantity'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %% [markdown]
# define the correlation between all columns

# %% [markdown]
# creat a new column of price by multiple of price and quantity column

# %%
data['Profit']=data['Quantity']*data['Price']
data
# Out:
#                    Distributor                               Customer Name  \
# 0       Gottlieb-Cruickshank                       Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                    Feest PLC
# 2       Gottlieb-Cruickshank          Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                         Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# ...                        ...                                         ...
# 254077    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 254078    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 254079    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 254080    Bashirian-Kassulke                        Balistreri Group Pharm
# 254081    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %% [markdown]
# group the data by distributor and count the number of product name

# %%
each_distributor_prod=data.groupby('Distributor')['Product Name'].count().reset_index()
each_distributor_prod
# Out:
#                Distributor  Product Name
# 0     Bashirian-Kassulke             178
# 1                  Beier            3311
# 2            Carter-Conn             181
# 3                 Cassin            3007
# 4               Crist Inc           1157
# 5       Daugherty-Rempel            1960
# 6                 Erdman           26238
# 7             Gerlach LLC         111364
# 8               Gleason              779
# 9   Gottlieb-Cruickshank            6427
# 10        Graham and Sons            213
# 11      Hansen Group Pharm           318
# 12                 Koss            58360
# 13         Kozey-Emmerich           4305
# 14              Kris LLC              52
# 15                Lesch              974
# 16  Lindgren-Simonis Pharm           759
# 17               Lockman            1013
# 18         Nader-Gaylord             324
# 19         Prohaska-Kuhic           6109
# 20           Rogahn-Klein            227
# 21                Rohan             1185
# ...

# %%
Country_sales
# Out:
#    Country         Sales
# 0  Germany  1.111811e+10
# 1   Poland  6.808798e+08

# %% [markdown]
# creat a new column of sales percentage by country

# %%
Country_sales['country_sales_per']=(Country_sales['Sales']*100)/Country_sales['Sales'].sum()
Country_sales
# Out:
#    Country         Sales  country_sales_per
# 0  Germany  1.111811e+10          94.229337
# 1   Poland  6.808798e+08           5.770663

# %% [markdown]
# convert the datatype of year column to datetime

# %%
data['Year']=pd.to_datetime(data['Year'])
data
# Out:
#                    Distributor                               Customer Name  \
# 0       Gottlieb-Cruickshank                       Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                    Feest PLC
# 2       Gottlieb-Cruickshank          Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                         Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# ...                        ...                                         ...
# 254077    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 254078    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 254079    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 254080    Bashirian-Kassulke                        Balistreri Group Pharm
# 254081    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254082 entries, 0 to 254081
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Distributor        254082 non-null  object
#  1   Customer Name      254082 non-null  object
#  2   City               254082 non-null  object
#  3   Country            254082 non-null  object
#  4   Latitude           254082 non-null  float64
#  5   Longitude          254082 non-null  float64
#  6   Channel            254082 non-null  object
#  7   Sub-channel        254082 non-null  object
#  8   Product Name       254082 non-null  object
#  9   Product Class      254082 non-null  object
#  10  Quantity           254082 non-null  float64
#  11  Price              254082 non-null  int64
#  12  Sales              254082 non-null  float64
#  13  Month              254082 non-null  object
#  14  Year               254082 non-null  datetime64[ns]
# ...

# %% [markdown]
# calculate the average price and standard deviation price of price column

# %%
data['Price'].mean(),data['Price'].std()
# Out:
# (412.2077203422517, 224.96368740592723)

# %% [markdown]
# define the correlaion between price and quantity

# %%
data['Price'].corr(data['Quantity'])
# Out:
# -0.0005318345925382081

# %% [markdown]
# group the data by city and sum of sales

# %%
city_sales=data.groupby('City')['Sales'].sum().reset_index()
city_sales
# Out:
#             City       Sales
# 0         Aachen  19090504.0
# 1          Aalen  13173562.0
# 2         Achern  21740500.0
# 3          Achim  18720448.0
# 4          Ahaus  18451676.0
# ..           ...         ...
# 744      Świecie   2021466.0
# 745  Świedbodzin   4390668.0
# 746  Świnoujście   4578864.0
# 747         Żary   3964929.0
# 748      Żychlin   3029636.0
#
# [749 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# creat a histogram plot of price column

# %%
plt.hist(data['Price'])
plt.show()

# %% [markdown]
# creat a box plot of price by sales

# %%
data.boxplot(column='Price',by='Product Class')
plt.show()

# %% [markdown]
# top 10 sales by customer

# %%
top_10_sales_customer=data.groupby('Customer Name')['Sales'].sum().nlargest(10).reset_index()
top_10_sales_customer
# Out:
#                                        Customer Name         Sales
# 0                              Mraz-Kutch Pharma Plc  9.356178e+07
# 1              Parker, Green and Emmerich Pharma Plc  6.489050e+07
# 2                                    Zemlak-Witting   5.600668e+07
# 3                      Moen, Murazik and Smith Pharm  5.088532e+07
# 4                       Mills Inc Pharmaceutical Ltd  4.593901e+07
# 5                                       Streich PLC   4.445462e+07
# 6  Gleichner, Bahringer and Morar Pharmaceutical ...  4.377938e+07
# 7                                       Reichel Inc   4.349563e+07
# 8               Romaguera, Moen and Hagenes Pharmacy  4.206666e+07
# 9               Torphy, Pfeffer and Jakubowski Pharm  4.151422e+07
